# %%
#Addition

a = 10
b = 15
print(a+b)
# Out:
# 25

# %%
a= int(input("enter first number: "))
b= int(input("enter second number: "))

print("Addition =", a + b)
# Out:
# enter first number:  8
# enter second number:  9
# Addition = 17

# %%
#Subtraction

a = 10
b = 6
print(a-b)
# Out:
# 4

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))

print("Subtraction =", a - b)
# Out:
# enter first number:  24
# enter second number:  18
# Subtraction = 6

# %%
mangoes = 15
given = 9

print("Remaining mangoes =", mangoes - given)
# Out:
# Remaining mangoes = 6

# %%
#Multiplication

a = 8
b = 6

print("Multiplication =", a * b)
# Out:
# Multiplication = 48

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
c = int(input("enter third number: "))

print("Multiplication =", a * b * c)
# Out:
# enter first number:  5
# enter second number:  7
# enter third number:  9
# Multiplication = 315

# %%
pen_per_box = 20
box = 6

print("Multiplication =", pen_per_box * box)
# Out:
# Multiplication = 120

# %%
#Division

a = 16
b = 4

print("Division =", a/b)
# Out:
# Division = 4.0

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))

print("Division =", a/b)
# Out:
# enter first number:  48
# enter second number:  6
# Division = 8.0
